# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(df,x='sepal_length',hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(df,x='sepal_width',hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(df,x='petal_length',hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.kdeplot(df,x='petal_width',hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# for ml we do feature selection in which we select best columns for prediction we distinguished those columns using pdf and we came to know that petal length and widht are columns that distinguish them the most like below 0.7 is setosa than >0.7 and <1.7
# is versicolor than the rest is verginica

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.kdeplot(df,x='petal_width',hue='species')
sns.ecdfplot(df,x='petal_width',hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %% [markdown]
# we made a decision by using above pdf that
# the ones who have petal_width > 0.7 and < 1.7 are
# versicolor now will prove that it means that at point < 1.7 the percentage of probability of being vericolor is 95% so in this range verginica has probablity of 10% so in point >1.7 verginca would have probability of 90%

# %%
sns.jointplot(df,x='petal_length',y='sepal_length',kind='kde',fill=True,cbar=True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.kdeplot(titanic,x='age',hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(titanic,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot((titanic['age']-titanic['age'].mean()) /titanic['age'].std())
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
titanic['age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
titanic['age'].mean() + 3*titanic['age'].std()
# Out:
# np.float64(73.27860964406095)

# %%
titanic['age'].mean() - 3*titanic['age'].std()
# Out:
# np.float64(-13.88037434994331)

# %%
titanic[(titanic['age'] > 73) & (titanic['age'] < 13)]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []
