# %%
from pickle import NONE
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

plt.style.use("ggplot")

# %% [markdown]
# ### `Q-1:` Using Gapminder Data
# 1. Create a scatter plot of 'gdpPercap' against 'lifeExp' for the year 2007, with the size of the markers determined by 'pop' and the color determined by 'continent'.

# %%
import plotly.express as px
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
tmp_df = df[df['year']==2007]

# %%
sns.relplot(tmp_df,x='gdpPercap',y='lifeExp',size='pop',hue='continent')

# %% [markdown]
# ### `Q-2-3:` Using `flights` dataset of seaborn.
#
# 2. Using the "flights" dataset that comes with seaborn, create a heatmap that shows the average number of passengers per month for each year.
#
# 3. Using the seaborn's flight dataset, create a clustermap to visualize the relationship between the number of passengers, months, and year.

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# 5    1949   Jun         135
# 6    1949   Jul         148
# 7    1949   Aug         148
# 8    1949   Sep         136
# 9    1949   Oct         119
# 10   1949   Nov         104
# 11   1949   Dec         118
# 12   1950   Jan         115
# 13   1950   Feb         126
# 14   1950   Mar         141
# 15   1950   Apr         135
# 16   1950   May         125
# 17   1950   Jun         149
# 18   1950   Jul         170
# 19   1950   Aug         170
# 20   1950   Sep         158
# 21   1950   Oct         133
# 22   1950   Nov         114
# 23   1950   Dec         140
# 24   1951   Jan         145
# 25   1951   Feb         150
# 26   1951   Mar         178
# 27   1951   Apr         163
# 28   1951   May         172
# 29   1951   Jun         178
# 30   1951   Jul         199
# 31   1951   Aug         199
# 32   1951   Sep         184
# 33   1951   Oct         162
# 34   1951   Nov         146
# 35   1951   Dec         166
# 36   1952   Jan         171
# 37   1952   Feb         180
# 38   1952   Mar         193
# 39   1952   Apr         181
# 40   1952   May         183
# 41   1952   Jun         218
# 42   1952   Jul         230
# 43   1952   Aug         242
# 44   1952   Sep         209
# 45   1952   Oct         191
# 46   1952   Nov         172
# 47   1952   Dec         194
# 48   1953   Jan         196
# 49   1953   Feb         196
# 50   1953   Mar         236
# 51   1953   Apr         235
# 52   1953   May         229
# 53   1953   Jun         243
# 54   1953   Jul         264
# 55   1953   Aug         272
# 56   1953   Sep         237
# 57   1953   Oct         211
# 58   1953   Nov         180
# 59   1953   Dec         201
# 60   1954   Jan         204
# 61   1954   Feb         188
# 62   1954   Mar         235
# 63   1954   Apr         227
# 64   1954   May         234
# 65   1954   Jun         264
# 66   1954   Jul         302
# 67   1954   Aug         293
# 68   1954   Sep         259
# 69   1954   Oct         229
# 70   1954   Nov         203
# 71   1954   Dec         229
# 72   1955   Jan         242
# 73   1955   Feb         233
# 74   1955   Mar         267
# 75   1955   Apr         269
# 76   1955   May         270
# 77   1955   Jun         315
# 78   1955   Jul         364
# 79   1955   Aug         347
# 80   1955   Sep         312
# 81   1955   Oct         274
# 82   1955   Nov         237
# 83   1955   Dec         278
# 84   1956   Jan         284
# 85   1956   Feb         277
# 86   1956   Mar         317
# 87   1956   Apr         313
# 88   1956   May         318
# 89   1956   Jun         374
# 90   1956   Jul         413
# 91   1956   Aug         405
# 92   1956   Sep         355
# 93   1956   Oct         306
# 94   1956   Nov         271
# 95   1956   Dec         306
# 96   1957   Jan         315
# 97   1957   Feb         301
# 98   1957   Mar         356
# 99   1957   Apr         348
# 100  1957   May         355
# 101  1957   Jun         422
# 102  1957   Jul         465
# 103  1957   Aug         467
# 104  1957   Sep         404
# 105  1957   Oct         347
# 106  1957   Nov         305
# 107  1957   Dec         336
# 108  1958   Jan         340
# 109  1958   Feb         318
# 110  1958   Mar         362
# 111  1958   Apr         348
# 112  1958   May         363
# 113  1958   Jun         435
# 114  1958   Jul         491
# 115  1958   Aug         505
# 116  1958   Sep         404
# 117  1958   Oct         359
# 118  1958   Nov         310
# 119  1958   Dec         337
# 120  1959   Jan         360
# 121  1959   Feb         342
# 122  1959   Mar         406
# 123  1959   Apr         396
# 124  1959   May         420
# 125  1959   Jun         472
# 126  1959   Jul         548
# 127  1959   Aug         559
# 128  1959   Sep         463
# 129  1959   Oct         407
# 130  1959   Nov         362
# 131  1959   Dec         405
# 132  1960   Jan         417
# 133  1960   Feb         391
# 134  1960   Mar         419
# 135  1960   Apr         461
# 136  1960   May         472
# 137  1960   Jun         535
# 138  1960   Jul         622
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
tmp_df = df.pivot(index='year',columns='month',values='passengers')

# %%
sns.heatmap(tmp_df)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.clustermap(tmp_df)

# %% [markdown]
# ## For questions 4-8:
#
# For these qestions, an insurance dataset is used. You can get details from [here](https://www.kaggle.com/datasets/thedevastator/insurance-claim-analysis-demographic-and-health). And if you want this dataset to use directly, then you can use this link: **https://docs.google.com/spreadsheets/d/e/2PACX-1vQVpcVtdYdZU4zU4-lqxt-iPHkyndDWs_aqEDUu9ZodlJ48Dku0PFgdXlj2N5RCmwXJrNtZLsI_wEVf/pub?gid=220677750&single=true&output=csv**

# %% [markdown]
# ### **`Q-4:`** Draw a scatter plot based on the below conditions:
# 1. x-axis should be "age" and y-axis should be "bmi".
# 2. For hue, size and style parameters use "diabetic", "gender" and "smoker" column respectively.
# 3. Add title to your chart.
# 4. Age should be less than 70 percentiles.
# 5. BMI should be greater than the average value of the filtered age dataset.

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQVpcVtdYdZU4zU4-lqxt-iPHkyndDWs_aqEDUu9ZodlJ48Dku0PFgdXlj2N5RCmwXJrNtZLsI_wEVf/pub?gid=220677750&single=true&output=csv')
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
x = np.nanpercentile(df['age'].values,70)

# %%
df['filtered_age'] = df[df['age'] < x]['age']

# %%
y = df['filtered_age'].mean()

# %%
tmp_df = df[df['bmi'] > y]

# %%
sns.scatterplot(tmp_df,x='filtered_age',y='bmi',hue='diabetic',size='gender',style='smoker')
plt.title('Scatter')
# Out:
# Text(0.5, 1.0, 'Scatter')

# %% [markdown]
# ### **`Q-5:`** Draw a line plot by using the below informations
#
# 1. bloodpressure vs children
# 2. Blood-pressure values should be between 90 and 100. The upper and lower limit are included.
# 3. Show the details of "smoker".

# %%
df.head(1)
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
#
#   smoker     region    claim  filtered_age
# 0     No  southeast  1121.87          39.0

# %%
tmp_df = df[(df['bloodpressure']<=100) & (df['bloodpressure']>=90)]

# %%
sns.relplot(tmp_df,x='bloodpressure',y='children',kind='line',hue='smoker',err_style=None)

# %% [markdown]
# ### **`Q-6:`** Draw a histogram using displot
#
# - based on "age" column.
# - Show details of "smoker" (hue).
# - Create 2 separate charts for the above 2 conditions based on "gender" side-by-side.

# %%
df.head(1)
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
#
#   smoker     region    claim  filtered_age
# 0     No  southeast  1121.87          39.0

# %%
sns.displot(df,kind='hist',x='age',hue='smoker',col='gender')

# %% [markdown]
# ### **`Q-7:`** Draw a kde plot between "age" and "bloodpressure".

# %%
sns.displot(df,kind='kde',x='age',y='bloodpressure')

# %% [markdown]
# ### **`Q-8:`** Draw a clustermap between between "age", "bmi" and "bloodpressure".

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim  filtered_age
# 0     No  southeast  1121.87          39.0
# 1     No  southeast  1131.51          24.0
# 2     No  southeast  1135.94           NaN
# 3     No  northwest  1136.40           NaN
# 4     No  northwest  1137.01           NaN

# %%
tmp_df=df.dropna()

# %%
sns.clustermap(tmp_df[['age','bmi','bloodpressure']])
