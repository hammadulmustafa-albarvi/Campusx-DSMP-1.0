# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Value counts(series and dataframe)

# %%
marks = pd.DataFrame([
    [100,45,32],
    [65,76,34],
    [12,96,40]
],columns=['iq','marks','package'])
marks
# Out:
#     iq  marks  package
# 0  100     45       32
# 1   65     76       34
# 2   12     96       40

# %%
marks.value_counts()
# Out:
# iq   marks  package
# 12   96     40         1
# 65   76     34         1
# 100  45     32         1
# Name: count, dtype: int64

# %%
 ipl = pd.read_csv("/content/ipl-matches.csv")

# %%
# max number of player of the match by players in special mathces
ipl[~(ipl['MatchNumber'].str.isdigit())]['Player_of_Match'].value_counts().head()
# Out:
# Player_of_Match
# F du Plessis      3
# SK Raina          3
# KA Pollard        3
# JJ Bumrah         2
# AB de Villiers    2
# Name: count, dtype: int64

# %%
# toss decision percentage
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team played
data = ipl['Team1'].value_counts() + ipl['Team2'].value_counts()
data
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %% [markdown]
# Sort Values

# %%
s = pd.Series([34,5,12,67])
s.sort_values(ascending=False)
# Out:
# 3    67
# 0    34
# 2    12
# 1     5
# dtype: int64

# %%
movies = pd.read_csv("/content/movies.csv")

# %%
movies.sort_values('title_x')
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# Rank(series)

# %%
 batsman = pd.read_csv("/content/batsman_runs_ipl.csv")

# %%
batsman['batting_rank'] = batsman['batsman_run'].rank(ascending=False)

# %%
batsman.head()
# Out:
#            batter  batsman_run  batting_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 4     A Choudhary           25         402.5

# %%
batsman.sort_values("batting_rank")
# Out:
#              batter  batsman_run  batting_rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# Sort Index (series and dataframe)

# %%
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# Set Index (dataframe)

# %%
batsman.set_index('batter',inplace=True)

# %% [markdown]
# Reset Index

# %%
batsman.reset_index()
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
# how to replace index without losing the column
batsman.reset_index().set_index('batter')
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
marks_series = pd.Series({
    "maths":68,
    "sciecne":23,
    "physics":45
})

# %%
marks_series
# Out:
# maths      68
# sciecne    23
# physics    45
# dtype: int64

# %%
marks_series.reset_index()
# Out:
#      index   0
# 0    maths  68
# 1  sciecne  23
# 2  physics  45

# %% [markdown]
# Rename dataframe

# %%
movies.set_index("title_x",inplace=True)

# %%
# changes in columns
movies.rename(columns={"wiki_link":"wikipedia"})
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#changes in inde
movies.rename(index={'Battalion 609' : 'Battalion'})
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion                              tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion                                                                           NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# Unique Series

# %%
movies['genres'].nunique() # nunique doesnt count Nan unique does
# Out:
# 205

# %% [markdown]
# Isnull (series , dataframe)

# %%
movies['tagline'][movies['tagline'].isnull()]
# Out:
# title_x
# Uri: The Surgical Strike                NaN
# Battalion 609                           NaN
# The Accidental Prime Minister (film)    NaN
# Why Cheat India                         NaN
# Evening Shadows                         NaN
#                                        ...
# Tera Mera Saath Rahen                   NaN
# Yeh Zindagi Ka Safar                    NaN
# Sabse Bada Sukh                         NaN
# Daaka                                   NaN
# Humsafar                                NaN
# Name: tagline, Length: 1072, dtype: object

# %% [markdown]
# notnull (series + dataframe)

# %%
movies['tagline'].notnull()
# Out:
# title_x
# Uri: The Surgical Strike                False
# Battalion 609                           False
# The Accidental Prime Minister (film)    False
# Why Cheat India                         False
# Evening Shadows                         False
#                                         ...
# Tera Mera Saath Rahen                   False
# Yeh Zindagi Ka Safar                    False
# Sabse Bada Sukh                         False
# Daaka                                   False
# Humsafar                                False
# Name: tagline, Length: 1629, dtype: bool

# %% [markdown]
# hasnans (series)

# %%
movies['tagline'].hasnans
# Out:
# True

# %%
movies.isnull()
# Out:
#                                       imdb_id  poster_path  wiki_link  \
# title_x
# Uri: The Surgical Strike                False        False      False
# Battalion 609                           False         True      False
# The Accidental Prime Minister (film)    False        False      False
# Why Cheat India                         False        False      False
# Evening Shadows                         False         True      False
# ...                                       ...          ...        ...
# Tera Mera Saath Rahen                   False        False      False
# Yeh Zindagi Ka Safar                    False        False      False
# Sabse Bada Sukh                         False         True      False
# Daaka                                   False        False      False
# Humsafar                                False        False      False
#
#                                       title_y  original_title  is_adult  \
# title_x
# ...

# %%
movies.notnull()
# Out:
#                                       imdb_id  poster_path  wiki_link  \
# title_x
# Uri: The Surgical Strike                 True         True       True
# Battalion 609                            True        False       True
# The Accidental Prime Minister (film)     True         True       True
# Why Cheat India                          True         True       True
# Evening Shadows                          True        False       True
# ...                                       ...          ...        ...
# Tera Mera Saath Rahen                    True         True       True
# Yeh Zindagi Ka Safar                     True         True       True
# Sabse Bada Sukh                          True        False       True
# Daaka                                    True         True       True
# Humsafar                                 True         True       True
#
#                                       title_y  original_title  is_adult  \
# title_x
# ...

# %% [markdown]
# Drop Na (series + dataframe)

# %%
movies['tagline']
# Out:
# title_x
# Uri: The Surgical Strike                NaN
# Battalion 609                           NaN
# The Accidental Prime Minister (film)    NaN
# Why Cheat India                         NaN
# Evening Shadows                         NaN
#                                        ...
# Tera Mera Saath Rahen                   NaN
# Yeh Zindagi Ka Safar                    NaN
# Sabse Bada Sukh                         NaN
# Daaka                                   NaN
# Humsafar                                NaN
# Name: tagline, Length: 1629, dtype: object

# %%
movies['tagline'].dropna()
# Out:
# title_x
# Bombairiya                               They didn't mean to change the world.
# Gully Boy                                                    Apna Time Aayega!
# Total Dhamaal                                       The Wildest Adventure Ever
# Mere Pyare Prime Minister                             Meri Ek Arzi Sun Lo Zara
# Yeh Hai India                                          A Film for Every Indian
#                                                    ...
# Maya (2001 film)             A child's innocence shattered by unreal tradit...
# Nayak (2001 Hindi film)                                        Fight the power
# Yeh Raaste Hain Pyaar Ke                Love is a journey... not a destination
# Tum Bin                                                   Love will find a way
# Zubeidaa                                               The Story of a Princess
# Name: tagline, Length: 557, dtype: object

# %%
movies.dropna(how='all')
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.dropna(subset=['tagline','actors'])
# Out:
#                              imdb_id  \
# title_x
# Bombairiya                 tt4971258
# Gully Boy                  tt2395469
# Total Dhamaal              tt7639372
# Mere Pyare Prime Minister  tt8207768
# Yeh Hai India              tt5525846
# ...                              ...
# Maya (2001 film)           tt0299027
# Nayak (2001 Hindi film)    tt0291376
# Yeh Raaste Hain Pyaar Ke   tt0292740
# Tum Bin                    tt0290326
# Zubeidaa                   tt0255713
#
#                                                                  poster_path  \
# title_x
# Bombairiya                 https://upload.wikimedia.org/wikipedia/en/thum...
# Gully Boy                  https://upload.wikimedia.org/wikipedia/en/thum...
# Total Dhamaal              https://upload.wikimedia.org/wikipedia/en/thum...
# Mere Pyare Prime Minister  https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India              https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# Fill na (series + dataframe)

# %%
movies['tagline'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-77-1053815475.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   movies['tagline'].fillna(method='ffill')
# title_x
# Uri: The Surgical Strike                                    NaN
# Battalion 609                                               NaN
# The Accidental Prime Minister (film)                        NaN
# Why Cheat India                                             NaN
# Evening Shadows                                             NaN
#                                                  ...
# Tera Mera Saath Rahen                   The Story of a Princess
# Yeh Zindagi Ka Safar                    The Story of a Princess
# Sabse Bada Sukh                         The Story of a Princess
# Daaka                                   The Story of a Princess
# Humsafar                                The Story of a Princess
# Name: tagline, Length: 1629, dtype: object

# %% [markdown]
# drop_duplicate (series + dataframe)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
temp = pd.Series([1,2,3,1,2,2,5])
temp.duplicated().sum()
# Out:
# np.int64(3)

# %%
temp.drop_duplicates(inplace=True,keep='last')
temp.duplicated().sum()
# Out:
# np.int64(0)

# %%
temp
# Out:
# 0    1
# 1    2
# 2    3
# 6    5
# dtype: int64

# %%
# find last match played by virat kohli in IPL
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl['all_players'] = ipl['Team1Players']+ipl['Team2Players']
ipl['kohli_play']  = ipl['all_players'].apply(lambda x : "V Kohli" in x)
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field  ...
#
#      WonBy Margin method  Player_of_Match  \
# 0  Wickets    7.0    NaN        HH Pandya
# 1  Wickets    7.0    NaN       JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1  \
# ...

# %%
ipl[(ipl['City'] == 'Delhi') & (ipl['kohli_play']==True)].drop_duplicates(subset=['City','kohli_play'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     kohli_play
# 208       True
#
# [1 rows x 22 columns]

# %% [markdown]
# Drop (series + dataframe)

# %%
tmp = pd.Series([2,4,5,2,132,521,12])
tmp.drop(index=[0,3])
# Out:
# 1      4
# 2      5
# 4    132
# 5    521
# 6     12
# dtype: int64

# %%
movies.drop(columns=['title_y','tagline']).head(1) # drop column
# Out:
#                             imdb_id  \
# title_x
# Uri: The Surgical Strike  tt8291224
#
#                                                                 poster_path  \
# title_x
# Uri: The Surgical Strike  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                   wiki_link  \
# title_x
# Uri: The Surgical Strike  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                                     original_title  is_adult  year_of_release  \
# title_x
# Uri: The Surgical Strike  Uri: The Surgical Strike         0             2019
#
#                          runtime            genres  imdb_rating  imdb_votes  \
# title_x
# Uri: The Surgical Strike     138  Action|Drama|War          8.4       35112
#
#                                                                       story  \
# title_x
# Uri: The Surgical Strike  Divided over five chapters  the film chronicle...
#
# ...

# %%
movies.drop(index=['Uri: The Surgical Strike','Battalion 609']).head(1)
# Out:
#                                         imdb_id  \
# title_x
# The Accidental Prime Minister (film)  tt6986710
#
#                                                                             poster_path  \
# title_x
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                               wiki_link  \
# title_x
# The Accidental Prime Minister (film)  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                                                             title_y  \
# title_x
# The Accidental Prime Minister (film)  The Accidental Prime Minister
#
#                                                      original_title  is_adult  \
# title_x
# The Accidental Prime Minister (film)  The Accidental Prime Minister         0
#
#                                       year_of_release runtime  \
# title_x
# The Accidental Prime Minister (film)             2019     112
#
# ...
