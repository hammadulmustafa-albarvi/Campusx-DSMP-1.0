# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
b=-100
m=78.5
lr=0.1
for i in range(10):
  loss_slope = -2 * np.sum(y-m*X.ravel() - b)
  b = b - (lr  * loss_slope)
  y_pred = m * X + b
  plt.plot(X,y_pred)
plt.plot(X,y)

# %%
X1,y1 = make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(X1,y1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X1,y1)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# np.float64(-0.4498600090508793)

# %%
class GDregressor:
  def __init__(self,learning_rate,epochs):
    self.m = 1
    self.b = 0
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self,X,y):
    for i in range(self.epochs):
      loss_slope = -2 * np.sum(y - self.m * X.ravel() - self.b)
      loss_slope_m = -2 * np.sum(((y - self.m * X.ravel() - self.b)) * X.ravel())
      self.m = self.m - (self.lr * loss_slope_m)
      self.b = self.b - (self.lr * loss_slope)
    print(self.b)
    print(self.m)

  def predict(self,X):
    return (self.m * X) + self.b

# %%
gd = GDregressor(0.001,5000)

# %%
gd.fit(X1,y1)
# Out:
# -0.44986000905087864
# 53.80826756105005

# %%
gd.predict(X1[0])
# Out:
# array([39.83082194])

# %%
from sklearn.model_selection import train_test_split

# %%
lr_ = LinearRegression()

# %%
X_train,X_test,y_train,y_test = train_test_split(X1,y1,random_state=2,test_size=0.2)

# %%
lr_.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr_.predict(X_test)
# Out:
# array([-36.04096475,  12.57393748,  25.19108919, -78.04651818,
#         32.19484716, 117.79630313,  56.27677758,  45.97015744,
#        -51.5459185 , -71.95408055,  56.67361973, -16.84470517,
#         44.854661  ,  22.67109885,  40.73339357, -59.50412266,
#        -38.41340711, -20.01609912, -85.8951082 ,  46.25397139])

# %%
lr_.coef_
# Out:
# array([52.33475146])

# %%
lr_.intercept_
# Out:
# np.float64(1.5557806521747182)

# %%
gd.fit(X_train,y_train)
# Out:
# 1.5557806521747202
# 52.33475145857771

# %%
y_pred = (gd.predict(X_test))

# %%
y_pred
# Out:
# array([[-36.04096475],
#        [ 12.57393748],
#        [ 25.19108919],
#        [-78.04651818],
#        [ 32.19484716],
#        [117.79630313],
#        [ 56.27677758],
#        [ 45.97015744],
#        [-51.5459185 ],
#        [-71.95408055],
#        [ 56.67361973],
#        [-16.84470517],
#        [ 44.854661  ],
#        [ 22.67109885],
#        [ 40.73339357],
#        [-59.50412266],
#        [-38.41340711],
#        [-20.01609912],
#        [-85.8951082 ],
#        [ 46.25397139]])

# %%
plt.scatter(X,y)
plt.plot(X_test,y_pred)
